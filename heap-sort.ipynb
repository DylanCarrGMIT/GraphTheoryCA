# %% [markdown]
# #What is the Heap Sort Algorithm?
# Heap Sort is a comparison-based sorting algorithm, created by J. W. J. Williams in 1964. Williams claimed that Heapsort is a combination of 2 different sorting algorithms, Treesort, and Tournament-sort. [1]
#
# The algorithm works by going through a heap of values, and adding the largest value in the heap to a second array, and updating the heap, and repeating until the heap is empty and a sorted array is produced.
#
# The general steps to implementing the heap sort algorithm are as follows:
# 1. Build a heap out of the data to be sorted. (Usually stored in an array with the layout of a binary tree)
# 2. Create a second array.
# 3. Populate the second array by looping through the heap, and adding the largest value in the heap to it.
# 4. Update heap after each removal
# <br>
#
# ![image-3.png](attachment:image-3.png) <br> Example of how data can be represented in a binary tree and an array.[2]

# %% [markdown]
# #References
# 1. Katajainen, J., 1996. The ultimate heapsort. Datalogisk Institut, Københavns Universitet.
# 2. https://en.wikipedia.org/wiki/Binary_heap#/media/File:Max-Heap.svg
